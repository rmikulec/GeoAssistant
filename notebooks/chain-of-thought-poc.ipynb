# %% [markdown]
# # Chain of Thought
#
#
# ## Purpose
# This notebook will look at the feasibility of using an LLM to run GIS analysis. Currently, GeoAgent can only set filters based on a pre-selected set of fields (determined by the vector store)
#
# ```mermaid
# flowchart LR
#     User --> |message|FieldDefStore
#     FieldDefStore --> |set of fields|LLM
#     LLM -->|field filters| Map
# ```
#
# ### Problem
# This is a very limited approach and has proved to be nothing more than a novelty. To really up the performance of this Agent, it needs to be allowed to *think* and plan out a strategy for analysis, then the python code executes it.
#
# *Soooo* if someone asks "Show me commercial properties in brooklyn close to 120kV transmission lines"
#
# The current approach will do something like
#
# 1. Run that quesiton through a store
# 1. Retrieve field defs like 'ZoneDist1', 'BoroCode', and 'VOLT_CLASS'
# 1. LLM will generate filters like "ZoneDist1 contains 'C'", "BoroCode=3", and "VOLT_CLASS=120"
# 1. The map will highlight these as two seperate map layers, one for the 'pluto' db and one for the 'transmission' db
#
# ### Solution
# What we need is to **first** have the LLM come up with a plan, just like an analyst would do
#
# Plan:
#   1. Find all the commercial properties in brooklyn
#   1. Find all the 120kV transmission lines
#   1. Intersect those two set, such that they are within 10 meters
#   1. Create new temp table
#   1. Use temp table to display layer
#
#
# ### Proposal
# Build a "chain-of-thought" type system, using strucutred outputs, to allow the LLM to preplan its analysis

# %% [markdown]
# ## First Step: Test out some PostGIS Queries
#
# First things first, lets test out some queries to create tables in PostGIS

# %%
from dotenv import load_dotenv
load_dotenv()

from geo_assistant.config import Configuration
from geo_assistant.agent._sql_exec import execute_template_sql
from sqlalchemy import create_engine, Engine, text

ENGINE = create_engine(Configuration.db_connection_url)

def drop_table(engine: Engine, table_name: str, schema: str = "public") -> None:
    """
    Drop a table if it exists.

    :param engine: SQLAlchemy Engine connected to your PostGIS database.
    :param table_name: Name of the table to drop (no schema).
    :param schema: Schema where the table lives (defaults to 'public').
    """
    qualified = f'"{schema}"."{table_name}"'
    drop_sql = text(f'DROP TABLE IF EXISTS {qualified} CASCADE;')
    # Use a transaction to ensure it commits
    with engine.begin() as conn:
        conn.execute(drop_sql)

# %% [markdown]
# ### Aggregate Table
#
# Creating a aggregate table works! Under a minute is fine too!!

# %%
execute_template_sql(
    engine=ENGINE,
    template_name="aggregate",
    output_table='test_aggregate',
    source_table="pluto",
    geometry_column="geometry",
    group_by=["BoroCode"]
)

# %% [markdown]
# ### Spatial Merge
#
# Spatial merges work as well!!

# %%
execute_template_sql(
    engine=ENGINE,
    template_name="merge",
    output_table="parcels_near_transmissions",
    left_table="pluto",
    right_table="transmission",
    geometry_column_left="geometry",
    geometry_column_right="geometry",
    spatial_predicate="dwithin",
    distance=10,
    keep_geometry="left",
)

# %% [markdown]
# ### Buffer Table
# And buffer table!!!

# %%
execute_template_sql(
    engine=ENGINE,
    template_name="buffer",
    source_table="parcels_near_transmissions",
    output_table="trans_parcel_halo",
    buffer_distance= 10,
    buffer_unit= "meters",
    srid_input= 4326,
    srid_tile= 3857,
    layer_name= "roads_halo",
    geometry_column="geometry"
)

# %% [markdown]
# ### Cleanup
#
# The experiment to dynamically create tables works great!! Just going to do some clean up

# %%
drop_table(ENGINE, "test_aggregate")
drop_table(ENGINE, "parcels_near_transmissions")
drop_table(ENGINE, "trans_parcel_halo")

# %% [markdown]
# ## Chain-Of-Thought
#
# Since it is proven that basic GIS operations can be parameterized, the next step is to test the LLM's ability to generate an analysis workflow
#
# One of the trickest steps to do is going to be limiting the columns by an Enum (use the vector store to not overwhelm with 100s of different fields)
#
# This will probably have to rely on some sort of dynamic Enum generation, then backfil the Enum to marked fields on the pydantic model

# %%
from typing import Type, Union
from pydantic import BaseModel, create_model

import json
from enum import Enum
from typing import Type, Self

def make_enum(*values: str) -> Type[Enum]:
    """
    Dynamically constructs an Enum subclass.

    - `name` is the Enum class name.
    - `values` are the allowed string values.
    
    Each member will be named as the upper-cased version of the value,
    and its `.value` will be the original string.
    """
    members = { val.upper(): val for val in values }
    return Enum("Fields", members)


DynamicField = Type[str]

class SQLStep(BaseModel):
    id: int

    class Config:
        validate_assignment = True

    @classmethod
    def with_fields(cls, fields_enum: type[Enum]) -> Type[Self]:
        """
        Return a new subclass of this model where every
        field annotated as DynamicField is replaced by Literal[options].
        """

        # find all the DynamicField markers and replace them
        dynamic_fields = {
            field_name: fields_enum
            for field_name, field_info in cls.model_fields.items()
            if field_info.annotation == DynamicField
        }
        dynamic_list_fields = {
            field_name: list[fields_enum]
            for field_name, field_info in cls.model_fields.items()
            if field_info.annotation == list[DynamicField]
        }
        
        # give it a distinct name so Pydantic can differentiate
        new_name = f"{cls.__name__}Dynamic"
        return create_model(
            new_name,
            __base__=cls,
            **(dynamic_fields | dynamic_list_fields)
        )

# %%
class AggregateStep(SQLStep):
    group_by: DynamicField
    columns: list[DynamicField]

fields = make_enum("dog", "cat")
AggregateStep.with_fields(fields).model_json_schema()
# Out:
# {'$defs': {'Fields': {'enum': ['dog', 'cat'],
#    'title': 'Fields',
#    'type': 'string'}},
#  'properties': {'id': {'title': 'Id', 'type': 'integer'},
#   'group_by': {'$ref': '#/$defs/Fields'},
#   'columns': {'items': {'$ref': '#/$defs/Fields'},
#    'title': 'Columns',
#    'type': 'array'}},
#  'required': ['id', 'group_by', 'columns'],
#  'title': 'AggregateStepDynamic',
#  'type': 'object'}

# %% [markdown]
# This seems to be a way to *mark* fields then backfill them with a dynamically generated enum. Now need to see if that enum is shared across all these types of classes, if part of a larger one (Needed to reduce context size)

# %%
class AggregateStep(SQLStep):
    group_by: DynamicField


class MergeStep(SQLStep):
    left_col: DynamicField


class GISAnalysis(BaseModel):
    steps: list[Union[AggregateStep, MergeStep]]

    @classmethod
    def backfill_fields(cls, *options: str) -> Type["GISAnalysis"]:
        """
        Returns a new GISAnalysis subclass where each of the step models
        (AggregateStep, MergeStep) has had its DynamicField replaced.
        """
        fields_enum = make_enum(*options)
        # generate dynamic versions of each SQLStep subclass
        dynamic_steps = [
            step_model.with_fields(fields_enum=fields_enum)
            for step_model in SQLStep.__subclasses__()
        ]
        # build Union[DynAgg, DynMerge]
        StepUnion = Union[tuple(dynamic_steps)]  # type: ignore[misc]

        # override only the 'steps' field
        return create_model(
            f"{cls.__name__}Dynamic",
            __base__=cls,
            steps=(list[StepUnion], ...)
        )

# %%
print(json.dumps(GISAnalysis.backfill_fields("dog", "cat").model_json_schema(), indent=2))
# Out:
# {
#   "$defs": {
#     "Fields": {
#       "enum": [
#         "dog",
#         "cat"
#       ],
#       "title": "Fields",
#       "type": "string"
#     },
#     "MergeStepDynamic": {
#       "properties": {
#         "id": {
#           "title": "Id",
#           "type": "integer"
#         },
#         "left_col": {
#           "$ref": "#/$defs/Fields"
#         }
#       },
#       "required": [
#         "id",
#         "left_col"
#       ],
#       "title": "MergeStepDynamic",
#       "type": "object"
#     },
#     "__main____AggregateStepDynamic__1": {
#       "properties": {
#         "id": {
#           "title": "Id",
#           "type": "integer"
#         },
#         "group_by": {
#           "$ref": "#/$defs/Fields"
#         },
#         "columns": {
#           "items": {
#             "$ref": "#/$defs/Fields"
#           },
#           "title": "Columns",
#           "type": "array"
#         }
#       },
#       "required": [
#         "id",
#         "group_by",
#         "columns"
#       ],
#       "title": "AggregateStepDynamic",
#       "type": "object"
#     },
#     "__main____AggregateStepDynamic__2": {
#       "properties": {
#         "id": {
#           "title": "Id",
#           "type": "integer"
#         },
#         "group_by": {
#           "$ref": "#/$defs/Fields"
#         }
#       },
#       "required": [
#         "id",
#         "group_by"
#       ],
#       "title": "AggregateStepDynamic",
#       "type": "object"
#     }
#   },
#   "properties": {
#     "steps": {
#       "items": {
#         "anyOf": [
#           {
#             "$ref": "#/$defs/__main____AggregateStepDynamic__1"
#           },
#           {
#             "$ref": "#/$defs/__main____AggregateStepDynamic__2"
#           },
#           {
#             "$ref": "#/$defs/MergeStepDynamic"
#           }
#         ]
#       },
#       "title": "Steps",
#       "type": "array"
#     }
#   },
#   "required": [
#     "steps"
#   ],
#   "title": "GISAnalysisDynamic",
#   "type": "object"
# }

# %% [markdown]
# This seemed to do it!! Gonna codify these blocks, then test to see if the LLM can properly generate an analysis

# %%
import json
from geo_assistant.agent._steps import _GISAnalysis, _AggregateStep, _BufferStep, _MergeStep, _FilterStep, _AddMapLayer
print(json.dumps(_GISAnalysis.model_json_schema(), indent=2))
# Out:
# {
#   "properties": {},
#   "title": "_GISAnalysis",
#   "type": "object"
# }

# %%
from geo_assistant.doc_stores import FieldDefinitionStore
from typing import get_args

field_store = FieldDefinitionStore(version="1.0.8")

user_question = "Can you show me commercial plots that are within a transmission line?"
fields = await field_store.query(user_question, k=10)
DynGISModel = _GISAnalysis.build_model(
    steps=[_AggregateStep, _MergeStep, _BufferStep, _FilterStep, _AddMapLayer],
    fields=[field['name'] for field in fields]
)
print(json.dumps(DynGISModel.model_json_schema(), indent=2))
# Out:
# {
#   "$defs": {
#     "AddMapLayer": {
#       "properties": {
#         "name": {
#           "description": "A descriptive name for the step",
#           "title": "Name",
#           "type": "string"
#         },
#         "reasoning": {
#           "description": "Description of what the step does, and why it is needed",
#           "title": "Reasoning",
#           "type": "string"
#         },
#         "source_table": {
#           "title": "Source Table",
#           "type": "string"
#         },
#         "layer_id": {
#           "description": "The id of the new map layer",
#           "title": "Layer Id",
#           "type": "string"
#         },
#         "color": {
#           "description": "Hex value of the color of the geometries",
#           "title": "Color",
#           "type": "string"
#         },
#         "filters": {
#           "items": {
#             "anyOf": [
#               {
#                 "$ref": "#/$defs/ValueFilter"
#               },
#               {
#                 "$ref": "#/$defs/ListFilter"
#               },
#               {
#                 "$ref": "#/$defs/BetweenFilter"
#               },
#               {
#                 "$ref": "#/$defs/NullFilter"
#               }
#             ]
#           },
#           "title": "Filters",
#           "type": "array"
#         }
#       },
#       "required": [
#         "name",
#         "reasoning",
#         "source_table",
#         "layer_id",
#         "color",
#         "filters"
#       ],
#       "title": "AddMapLayer",
#       "type": "object"
#     },
#     "AggregateStep": {
#       "properties": {
#         "name": {
#           "description": "A descriptive name for the step",
#           "title": "Name",
#           "type": "string"
#         },
#         "reasoning": {
#           "description": "Description of what the step does, and why it is needed",
#           "title": "Reasoning",
#           "type": "string"
#         },
#         "select": {
#           "items": {
#             "$ref": "#/$defs/Fields"
#           },
#           "title": "Select",
#           "type": "array"
#         },
#         "output_table": {
#           "description": "Name of the aggregated table",
#           "title": "Output Table",
#           "type": "string"
#         },
#         "source_table": {
#           "is_table": true,
#           "title": "Source Table",
#           "type": "string"
#         },
#         "aggregators": {
#           "description": "List of ways to aggregate columns",
#           "items": {
#             "anyOf": [
#               {
#                 "$ref": "#/$defs/CountAggregator"
#               },
#               {
#                 "$ref": "#/$defs/SumAggregator"
#               },
#               {
#                 "$ref": "#/$defs/AvgAggregator"
#               },
#               {
#                 "$ref": "#/$defs/MinAggregator"
#               },
#               {
#                 "$ref": "#/$defs/MaxAggregator"
#               }
#             ]
#           },
#           "title": "Aggregators",
#           "type": "array"
#         },
#         "spatial_aggregator": {
#           "anyOf": [
#             {
#               "enum": [
#                 "COLLECT",
#                 "UNION",
#                 "CENTROID",
#                 "EXTENT",
#                 "ENVELOPE",
#                 "CONVEXHULL"
#               ],
#               "type": "string"
#             },
#             {
#               "type": "null"
#             }
#           ],
#           "default": null,
#           "description": "List of ways to aggregate geometries",
#           "title": "Spatial Aggregator"
#         },
#         "group_by": {
#           "items": {
#             "$ref": "#/$defs/Fields"
#           },
#           "title": "Group By",
#           "type": "array"
#         }
#       },
#       "required": [
#         "name",
#         "reasoning",
#         "select",
#         "output_table",
#         "source_table",
#         "aggregators",
#         "group_by"
#       ],
#       "title": "AggregateStep",
#       "type": "object"
#     },
#     "AvgAggregator": {
#       "properties": {
#         "operator": {
#           "const": "AVG",
#           "title": "Operator",
#           "type": "string"
#         },
#         "alias": {
#           "anyOf": [
#             {
#               "type": "string"
#             },
#             {
#               "type": "null"
#             }
#           ],
#           "default": null,
#           "description": "Optional alias for the aggregated output",
#           "title": "Alias"
#         },
#         "column": {
#           "$ref": "#/$defs/Fields"
#         }
#       },
#       "required": [
#         "operator",
#         "column"
#       ],
#       "title": "AvgAggregator",
#       "type": "object"
#     },
#     "BetweenFilter": {
#       "properties": {
#         "column": {
#           "$ref": "#/$defs/Fields"
#         },
#         "operator": {
#           "const": "BETWEEN",
#           "title": "Operator",
#           "type": "string"
#         },
#         "lower": {
#           "anyOf": [
#             {
#               "type": "string"
#             },
#             {
#               "type": "integer"
#             },
#             {
#               "type": "number"
#             }
#           ],
#           "title": "Lower"
#         },
#         "upper": {
#           "anyOf": [
#             {
#               "type": "string"
#             },
#             {
#               "type": "integer"
#             },
#             {
#               "type": "number"
#             }
#           ],
#           "title": "Upper"
#         }
#       },
#       "required": [
#         "column",
#         "operator",
#         "lower",
#         "upper"
#       ],
#       "title": "BetweenFilter",
#       "type": "object"
#     },
#     "BufferStep": {
#       "properties": {
#         "name": {
#           "description": "A descriptive name for the step",
#           "title": "Name",
#           "type": "string"
#         },
#         "reasoning": {
#           "description": "Description of what the step does, and why it is needed",
#           "title": "Reasoning",
#           "type": "string"
#         },
#         "select": {
#           "items": {
#             "$ref": "#/$defs/Fields"
#           },
#           "title": "Select",
#           "type": "array"
#         },
#         "output_table": {
#           "description": "Name of table being created",
#           "title": "Output Table",
#           "type": "string"
#         },
#         "source_table": {
#           "is_table": true,
#           "title": "Source Table",
#           "type": "string"
#         },
#         "buffer_distance": {
#           "description": "Distance to buffer",
#           "title": "Buffer Distance",
#           "type": "number"
#         },
#         "buffer_unit": {
#           "default": "meters",
#           "description": "Unit for the buffer distance. MUST be greater than 1. A buffer of 0 will result in an empty polygon",
#           "enum": [
#             "meters",
#             "kilometers"
#           ],
#           "title": "Buffer Unit",
#           "type": "string"
#         }
#       },
#       "required": [
#         "name",
#         "reasoning",
#         "select",
#         "output_table",
#         "source_table",
#         "buffer_distance"
#       ],
#       "title": "BufferStep",
#       "type": "object"
#     },
#     "CountAggregator": {
#       "properties": {
#         "operator": {
#           "const": "COUNT",
#           "title": "Operator",
#           "type": "string"
#         },
#         "alias": {
#           "anyOf": [
#             {
#               "type": "string"
#             },
#             {
#               "type": "null"
#             }
#           ],
#           "default": null,
#           "description": "Optional alias for the aggregated output",
#           "title": "Alias"
#         },
#         "column": {
#           "$ref": "#/$defs/Fields"
#         },
#         "distinct": {
#           "default": false,
#           "description": "Whether to count only distinct values",
#           "title": "Distinct",
#           "type": "boolean"
#         }
#       },
#       "required": [
#         "operator",
#         "column"
#       ],
#       "title": "CountAggregator",
#       "type": "object"
#     },
#     "Fields": {
#       "enum": [
#         "OWNER",
#         "Overlay1",
#         "Overlay2",
#         "VOLT_CLASS",
#         "VOLTAGE",
#         "CommFAR",
#         "SUB_2",
#         "SUB_1",
#         "ZoneDist2",
#         "LotFront"
#       ],
#       "title": "Fields",
#       "type": "string"
#     },
#     "FilterStep": {
#       "properties": {
#         "name": {
#           "description": "A descriptive name for the step",
#           "title": "Name",
#           "type": "string"
#         },
#         "reasoning": {
#           "description": "Description of what the step does, and why it is needed",
#           "title": "Reasoning",
#           "type": "string"
#         },
#         "select": {
#           "items": {
#             "$ref": "#/$defs/Fields"
#           },
#           "title": "Select",
#           "type": "array"
#         },
#         "output_table": {
#           "description": "Name of table being created",
#           "title": "Output Table",
#           "type": "string"
#         },
#         "source_table": {
#           "is_table": true,
#           "title": "Source Table",
#           "type": "string"
#         },
#         "filters": {
#           "items": {
#             "anyOf": [
#               {
#                 "$ref": "#/$defs/ValueFilter"
#               },
#               {
#                 "$ref": "#/$defs/ListFilter"
#               },
#               {
#                 "$ref": "#/$defs/BetweenFilter"
#               },
#               {
#                 "$ref": "#/$defs/NullFilter"
#               }
#             ]
#           },
#           "title": "Filters",
#           "type": "array"
#         }
#       },
#       "required": [
#         "name",
#         "reasoning",
#         "select",
#         "output_table",
#         "source_table",
#         "filters"
#       ],
#       "title": "FilterStep",
#       "type": "object"
#     },
#     "ListFilter": {
#       "properties": {
#         "column": {
#           "$ref": "#/$defs/Fields"
#         },
#         "operator": {
#           "enum": [
#             "IN",
#             "NOT IN"
#           ],
#           "title": "Operator",
#           "type": "string"
#         },
#         "value_list": {
#           "description": "List of values for IN / NOT IN",
#           "items": {
#             "anyOf": [
#               {
#                 "type": "string"
#               },
#               {
#                 "type": "integer"
#               },
#               {
#                 "type": "number"
#               }
#             ]
#           },
#           "title": "Value List",
#           "type": "array"
#         }
#       },
#       "required": [
#         "column",
#         "operator",
#         "value_list"
#       ],
#       "title": "ListFilter",
#       "type": "object"
#     },
#     "MaxAggregator": {
#       "properties": {
#         "operator": {
#           "const": "MAX",
#           "title": "Operator",
#           "type": "string"
#         },
#         "alias": {
#           "anyOf": [
#             {
#               "type": "string"
#             },
#             {
#               "type": "null"
#             }
#           ],
#           "default": null,
#           "description": "Optional alias for the aggregated output",
#           "title": "Alias"
#         },
#         "column": {
#           "$ref": "#/$defs/Fields"
#         }
#       },
#       "required": [
#         "operator",
#         "column"
#       ],
#       "title": "MaxAggregator",
#       "type": "object"
#     },
#     "MergeStep": {
#       "properties": {
#         "name": {
#           "description": "A descriptive name for the step",
#           "title": "Name",
#           "type": "string"
#         },
#         "reasoning": {
#           "description": "Description of what the step does, and why it is needed",
#           "title": "Reasoning",
#           "type": "string"
#         },
#         "select": {
#           "items": {
#             "$ref": "#/$defs/Fields"
#           },
#           "title": "Select",
#           "type": "array"
#         },
#         "output_table": {
#           "description": "Name of table being created",
#           "title": "Output Table",
#           "type": "string"
#         },
#         "left_table": {
#           "is_table": true,
#           "title": "Left Table",
#           "type": "string"
#         },
#         "right_table": {
#           "is_table": true,
#           "title": "Right Table",
#           "type": "string"
#         },
#         "spatial_predicate": {
#           "description": "ST_<predicate> or DWithin",
#           "enum": [
#             "intersects",
#             "contains",
#             "within",
#             "dwithin"
#           ],
#           "title": "Spatial Predicate",
#           "type": "string"
#         },
#         "distance": {
#           "anyOf": [
#             {
#               "type": "number"
#             },
#             {
#               "type": "null"
#             }
#           ],
#           "default": null,
#           "description": "Buffer distance (only for dwithin)",
#           "title": "Distance"
#         },
#         "keep_geometry": {
#           "default": "left",
#           "description": "Which geometry column to keep in the output",
#           "enum": [
#             "left",
#             "right"
#           ],
#           "title": "Keep Geometry",
#           "type": "string"
#         }
#       },
#       "required": [
#         "name",
#         "reasoning",
#         "select",
#         "output_table",
#         "left_table",
#         "right_table",
#         "spatial_predicate"
#       ],
#       "title": "MergeStep",
#       "type": "object"
#     },
#     "MinAggregator": {
#       "properties": {
#         "operator": {
#           "const": "MIN",
#           "title": "Operator",
#           "type": "string"
#         },
#         "alias": {
#           "anyOf": [
#             {
#               "type": "string"
#             },
#             {
#               "type": "null"
#             }
#           ],
#           "default": null,
#           "description": "Optional alias for the aggregated output",
#           "title": "Alias"
#         },
#         "column": {
#           "$ref": "#/$defs/Fields"
#         }
#       },
#       "required": [
#         "operator",
#         "column"
#       ],
#       "title": "MinAggregator",
#       "type": "object"
#     },
#     "NullFilter": {
#       "properties": {
#         "column": {
#           "$ref": "#/$defs/Fields"
#         },
#         "operator": {
#           "enum": [
#             "IS NULL",
#             "IS NOT NULL"
#           ],
#           "title": "Operator",
#           "type": "string"
#         }
#       },
#       "required": [
#         "column",
#         "operator"
#       ],
#       "title": "NullFilter",
#       "type": "object"
#     },
#     "SumAggregator": {
#       "properties": {
#         "operator": {
#           "const": "SUM",
#           "title": "Operator",
#           "type": "string"
#         },
#         "alias": {
#           "anyOf": [
#             {
#               "type": "string"
#             },
#             {
#               "type": "null"
#             }
#           ],
#           "default": null,
#           "description": "Optional alias for the aggregated output",
#           "title": "Alias"
#         },
#         "column": {
#           "$ref": "#/$defs/Fields"
#         }
#       },
#       "required": [
#         "operator",
#         "column"
#       ],
#       "title": "SumAggregator",
#       "type": "object"
#     },
#     "ValueFilter": {
#       "properties": {
#         "column": {
#           "$ref": "#/$defs/Fields"
#         },
#         "operator": {
#           "enum": [
#             "=",
#             "!=",
#             ">",
#             "<",
#             ">=",
#             "<=",
#             "LIKE",
#             "ILIKE"
#           ],
#           "title": "Operator",
#           "type": "string"
#         },
#         "value": {
#           "anyOf": [
#             {
#               "type": "string"
#             },
#             {
#               "type": "integer"
#             },
#             {
#               "type": "number"
#             }
#           ],
#           "description": "Single value for comparisons",
#           "title": "Value"
#         }
#       },
#       "required": [
#         "column",
#         "operator",
#         "value"
#       ],
#       "title": "ValueFilter",
#       "type": "object"
#     }
#   },
#   "properties": {
#     "steps": {
#       "items": {
#         "anyOf": [
#           {
#             "$ref": "#/$defs/AggregateStep"
#           },
#           {
#             "$ref": "#/$defs/MergeStep"
#           },
#           {
#             "$ref": "#/$defs/BufferStep"
#           },
#           {
#             "$ref": "#/$defs/FilterStep"
#           },
#           {
#             "$ref": "#/$defs/AddMapLayer"
#           }
#         ]
#       },
#       "title": "Steps",
#       "type": "array"
#     }
#   },
#   "required": [
#     "steps"
#   ],
#   "title": "GISAnalysis",
#   "type": "object"
# }

# %% [markdown]
# ### OpenAI Tests
#
# Ok, lets try sending this schema to openai with a nice system message and context and see what it does!!

# %%
import openai
import pathlib
from jinja2 import Template

system_message_template = Template(source=pathlib.Path("./geo_assistant/agent/system_message.j2").read_text())

# %%
from geo_assistant.doc_stores import SupplementalInfoStore, FieldDefinitionStore
from geo_assistant.config import Configuration
user_question = "transmission lines near commercial"
field_store = FieldDefinitionStore(version="1.0.8")
fields = await field_store.query(user_question)
info_store = SupplementalInfoStore(version="1.0.8")
context = await info_store.query(user_question, k=5)

# %%
system_message = system_message_template.render(
    field_definitions=fields,
    context_info=context
)
print(system_message)
# Out:
# You are an expert GIS analyst and spatial database architect with deep experience in PostGIS, pg-tileserv, and vector-tile workflows.
#
# ### Instructions
# 1. Think through your analysis step by step before producing any output.
# 2. Produce only valid JSON that conforms exactly to the `GISAnalysis` schema below.
# 3. Do **not** include any explanatory text outside the JSON object.
#
# *NOTE* All tables are already spatially indexed.
#
# ### Available Data
#
# -- Field Definitions --
# You have access to the following table fields:
# **transmission.OWNER** (string)
# Owner of the transmission line.
#
# **transmission.VOLT_CLASS** (string)
# Voltage of the transmission line grouped in industry standard classifications.
#
# **pluto.Overlay1** (string)
# The commercial overlay assigned to the tax lo t. A commercial overlay is a C1 or C2
#   zoning district mapped within residential z oning districts to serve local retail needs
#   (grocery stores, dry cleaners, restaurants, for example).
#
#   If more than one commercial overlay exists on the tax lot, COMMERCIAL
#   OVERLAY 1 represents the commercial overlay  occupying the greatest percentage of
#   the lot area. The commercial overlay district must either cover at least 10% of a tax
#   lot’s area or at least 50% of the commercial overlay district must be contained within
#   the tax lot.
#
#   If the tax lot does not contain a commercial overlay, the field is blank.
#
#   See SPLIT BOUNDARY INDICATOR to determine if the tax lot is divided.
#
# **transmission.VOLTAGE** (number)
# Carrying capacity of the transmission line in kilovolts.
#
# **pluto.Overlay2** (string)
# A commercial overlay assigned to the tax lot.
#   If the tax lot has more than one co mmercial overlays, COMMERCIAL OVERLAY 2
#   represents the commercial overlay occupying the second largest percentage of the tax
#   lot's area. The commercial overlay district mu st either cover at least 10% of a tax lot’s
#   area or at least 50% of the commercial overlay district must be contained within the tax lot.
#
#   If the tax lot is not divided by two commercial overlays the field is blank.
#
#   See SPLIT BOUNDARY INDICATOR to determine if the tax lot is divided.
#
#
#
# -- Context Information --
# You may reference this context for business logic, user goals, or other insights:
# ---
# **9. Citation & Identification** (source: Metadata_transmission_lines_hifld_v5.pdf)
# | Metadata Element            | Value |
# |-----------------------------|-------|
# | Title                       | Transmission Lines |
# | Presentation Formats        | digital map |
# | Dataset Languages           | English (UNITED STATES) |
# | Spatial Representation Type | vector |
# | ArcGIS Item Name            | transmission_line_hifld_v5 |
# | Publication Date            | 2022-12-14 |
#
# ---
# **ArcGIS Feature Class Properties** (source: Metadata_transmission_lines_hifld_v5.pdf)
# Feature Class: transmission_line_hifld_v5
#
# | Property              | Value   |
# |-----------------------|---------|
# | Feature Type          | Simple  |
# | Geometry Type         | Polyline|
# | Has Topology          | FALSE   |
# | Spatial Index         | TRUE    |
# | Linear Referencing    | FALSE   |
# ---
# **Spatial Data Properties** (source: Metadata_transmission_lines_hifld_v5.pdf)
# **Data Type:** VECTOR
#
# • Level of Topology for this Dataset: geometry only
#
# **Geometric Objects**
#
# • Feature Class Name: transmission_line_hifld_v5
# • Object Type: composite
# ---
# **Fields Detail: transmission_line_hifld_v5** (source: Metadata_transmission_lines_hifld_v5.pdf)
# **Object Type:** Feature Class
#
# **General Definition:**
# Attribute fields were populated using sources identified in the SOURCE field for the period covered in the Time Period metadata and other open source data. For string and date data types, NOT AVAILABLE values denote missing data that was not present in the source data. For numeric data types, -999999 denotes missing data that was not present in the source data. However, the missing data may be present in other sources not yet discovered and used in the creation and/or maintenance of this dataset. These records may be populated with valid information in future update cycles.
#
# | Field      | Alias     | Data Type | Width | Precision | Scale | Description                                           | Source        |
# |------------|-----------|-----------|-------|-----------|-------|-------------------------------------------------------|---------------|
# | OBJECTID   | OBJECTID  | OID       | 4     | 0         | 0     | Internal feature number. Sequential unique whole numbers automatically generated. | Esri          |
# | SHAPE      | SHAPE     | Geometry  | 0     | 0         | 0     | Feature geometry. Coordinates defining the features. | Esri          |
# | ID         | ID        | String    | 10    | 0         | 0     | Unique ID for each feature. Values unique to this dataset and may change between versions. | Originator defined |
# | TYPE       | TYPE      | String    | 60    | 0         | 0     | Specific categorical breakdown for the feature. Categories are not mutually exclusive. | Originator defined |
#
# **Enumerated Domain: TYPE**
#
# | Value         | Description                                           | Definition Source     |
# |---------------|-------------------------------------------------------|-----------------------|
# | AC            | Alternating current transmission line.               | Originator defined    |
# | DC            | Direct current transmission line.                    | Originator defined    |
# | OVERHEAD      | Overhead transmission line.                          | Originator defined    |
# | UNDERGROUND   | Underground transmission line.                       | Originator defined    |
# | NOT AVAILABLE | Please see "Entity Type Definition" section         | Originator defined    |
# ---
# **U. UTILITY BUREAU PROPERTIES** (source: pluto_datadictionary.pdf)
# | Code | Description |
# |------|-------------|
# | 0   | Utility Company Land and Building |
# | 1   | Bridge, Tunnel, Highway |
# | 2   | Gas or Electric Utility |
# | 3   | Ceiling Railroad |
# | 4   | Telephone Utility |
#
#
# ### Task
# Plan and output a detailed, multi-step GIS analysis pipeline.
# - `MergeStep`: Merge data from two seperate tables
# - `AggregateStep`: Aggregate data in a table
# - `BufferStep`: Create a buffer aroung geometry in a table
# - `FilterStep`: Filter a table
# - `AddMapLayer`: Add a layer to the map. Layer's point to a specific table. Usually the last step of and analysis.
#
# ### Important Considerations
# Make sure that columns needed in step i are selected in step i-1 (meaning that each steps always have the right columns available)
# When selecting columns from an `output_table` of a previous step, be aware that available columns might have changed (e.g., through aggregation or merging). Carefully confirm that you are referencing only columns available from that specific `output_table`.
# When building filters, make sure the 'value' type matches that of the field definition
#
# -- Available Tables --
# When referencing another table, ONLY these values and the `output_table` of a previous step can be used:
#
#
# ### Output Schema
#
# ```json
# {
#   "steps": [
#     {
#       "type": "<StepType>",
#       // step-specific parameters
#     }
#     // additional steps...
#   ]
# }

# %%
res = openai.Client(api_key=Configuration.openai_key).responses.parse(
    input=[
        {'role': 'system', 'content': system_message},
        {'role': 'user', 'content': user_question}
    ],
    model="o4-mini",
    reasoning={
        "effort":"high",
    },
    text_format=DynGISModel
)

# %%
print(res.output_parsed.model_dump_json(indent=2))
# Out:
# {
#   "steps": [
#     {
#       "id_": "5cfa1682-52e5-43d2-bc71-2b73d12a8d68",
#       "name": "Filter commercial overlay parcels",
#       "reasoning": "Filter pluto table to only parcels that have a primary commercial overlay",
#       "select": [
#         "Overlay1"
#       ],
#       "output_table": "pluto_commercial",
#       "source_table": "pluto",
#       "filters": [
#         {
#           "column": "Overlay1",
#           "operator": "IS NOT NULL"
#         },
#         {
#           "column": "Overlay1",
#           "operator": "!=",
#           "value": ""
#         }
#       ]
#     },
#     {
#       "id_": "b179ebca-251c-4920-ae72-9094b0e7f7ee",
#       "name": "Find transmission lines near commercial parcels",
#       "reasoning": "Identify transmission lines that are within 100 units of commercial parcels",
#       "select": [
#         "OWNER",
#         "VOLT_CLASS",
#         "VOLTAGE",
#         "Overlay1"
#       ],
#       "output_table": "transmission_near_commercial",
#       "left_table": "transmission",
#       "right_table": "pluto_commercial",
#       "spatial_predicate": "dwithin",
#       "distance": 100.0,
#       "keep_geometry": "left"
#     },
#     {
#       "id_": "4cd7e4ef-afc1-4de5-a948-0875771758a6",
#       "name": "Transmission lines near commercial areas",
#       "reasoning": "Add the resulting transmission lines within 100 units of commercial overlay parcels to the map",
#       "source_table": "transmission_near_commercial",
#       "layer_id": "transmission_near_commercial",
#       "color": "#FF0000",
#       "filters": []
#     }
#   ]
# }
